# %%
from Check_signal import *
check_signal()
# Out:
# Run number: 730253
# 730253 -- N spill: 1529 -- events in x1: 152144
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1771/2384514097.py in <module>
#       1 from Check_signal import *
# ----> 2 check_signal()
#
# /eos/home-i00/n/nicanale/eplusBOOST_2025_T9/OM/Check_signal.py in check_signal()
#     309         }
#     310     else:
# --> 311         cuts[run] = {'x_cry_cut': [4.6, 4.9], 'y_cry_cut': [4.7, 5.15]}
#     312
#     313     # Recupera tagli corretti per run_number
#
# NameError: name 'run' is not defined
